# %%
from sklearn.svm import LinearSVC
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
centers = [ (-1, -0.125), (0.5, 0.5)]

X, y = make_blobs(n_samples=50, n_features=2, centers=centers, cluster_std=.3)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
model = LinearSVC()

model.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
y_pred = model.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train[:,0], X_train[:,1], c=y_train)

# %%
plt.scatter(X_test[:,0], X_test[:,1], c=y_test)

# %% [markdown]
# # Kernel

# %%
from sklearn.svm import SVC
from sklearn.datasets import make_gaussian_quantiles
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X, y = make_gaussian_quantiles(n_features=2, n_classes=2, n_samples=300)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

model = SVC(gamma='auto')

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9333333333333333

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

# %%
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred)

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def fun(x, y):
    return 5 - (x**2 + y**2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X_, Y_ = np.meshgrid(np.array(X)[:,0],np.array(X)[:,1])
zs = np.array([fun(x, y) for x, y in zip(np.ravel(X_), np.ravel(Y_))])
Z = zs.reshape(X_.shape)

#ax.plot_surface(X_, Y_, Z)

zs2 = np.array([fun(x, y) for x, y in zip(np.array(X)[:,0],np.array(X)[:,1])])
ax.scatter(np.array(X)[:,0],np.array(X)[:,1], zs2, c=y)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5, 0, 'Z')
